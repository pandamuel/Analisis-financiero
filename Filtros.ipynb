# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
#import seaborn as sns
mpl.style.use('ggplot')

# %%
import pandas as pd
ruta="/workspaces/Analisis-financiero/"
tabla=pd.read_csv( ruta + 'fra.csv',sep=',',encoding='utf-8')
tabla
# Out:
# /tmp/ipykernel_123480/1694186895.py:3: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   tabla=pd.read_csv( ruta + 'fra.csv',sep=',',encoding='utf-8')
#                          DESCRIPCION_CONDUCTA                 ARMAS_MEDIOS  \
# 0                ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# 1                ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# 2                ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# 3                ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# 4                ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# ...                                       ...                          ...
# 100988  ARTÍCULO 229. VIOLENCIA INTRAFAMILIAR          SIN EMPLEO DE ARMAS
# 100989  ARTÍCULO 229. VIOLENCIA INTRAFAMILIAR          SIN EMPLEO DE ARMAS
# 100990  ARTÍCULO 229. VIOLENCIA INTRAFAMILIAR                 CONTUNDENTES
# ...

# %%
tabla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100993 entries, 0 to 100992
# Data columns (total 26 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   DESCRIPCION_CONDUCTA  100993 non-null  object
#  1   ARMAS_MEDIOS          100993 non-null  object
#  2   BARRIOS_HECHO         100993 non-null  object
#  3   FECHA_HECHO           100993 non-null  object
#  4   HORA_HECHO            100993 non-null  object
#  5   EDAD                  100360 non-null  object
#  6   SEXO                  100993 non-null  object
#  7   MOVIL_VICTIMA         100993 non-null  object
#  8   MOVIL_AGRESOR         100993 non-null  object
#  9   CLASE_SITIO           100993 non-null  object
#  10  ARTICULO              100993 non-null  object
#  11  DELITO_SOLO           100993 non-null  object
#  12  CURSO_VIDA            100993 non-null  object
#  13  CURSO_VIDA_ORDEN      100993 non-null  int64
# ...

# %% [markdown]
# <div align="center">
#     <span style="color:red; font-size:32px; font-weight:bold;">
#          Filtros Femenino
#     </span>
# </div>

# %%
tabla['SEXO'].value_counts()
# Out:
# SEXO
# FEMENINO         46749
# MASCULINO        45133
# NO DISPONIBLE     9111
# Name: count, dtype: int64

# %%
Filtro_Femenino=tabla['SEXO'].unique()
Filtro_Femenino
# Out:
# array(['MASCULINO', 'FEMENINO', 'NO DISPONIBLE'], dtype=object)

# %%
Filtro_Femenino=tabla[tabla['SEXO']=='FEMENINO']
Filtro_Femenino
# Out:
#                          DESCRIPCION_CONDUCTA                 ARMAS_MEDIOS  \
# 1651             ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# 1652             ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# 1653             ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# 1654             ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# 1655             ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# ...                                       ...                          ...
# 100988  ARTÍCULO 229. VIOLENCIA INTRAFAMILIAR          SIN EMPLEO DE ARMAS
# 100989  ARTÍCULO 229. VIOLENCIA INTRAFAMILIAR          SIN EMPLEO DE ARMAS
# 100990  ARTÍCULO 229. VIOLENCIA INTRAFAMILIAR                 CONTUNDENTES
# 100991  ARTÍCULO 229. VIOLENCIA INTRAFAMILIAR          SIN EMPLEO DE ARMAS
# 100992  ARTÍCULO 229. VIOLENCIA INTRAFAMILIAR          SIN EMPLEO DE ARMAS
#
#             BARRIOS_HECHO FECHA_HECHO HORA_HECHO  EDAD      SEXO  \
# ...

# %%
SEXO_1=tabla['SEXO'].unique()
SEXO_1
# Out:
# array(['MASCULINO', 'FEMENINO', 'NO DISPONIBLE'], dtype=object)

# %% [markdown]
# <div align="center">
#     <span style="color:red; font-size:32px; font-weight:bold;">
#          Filtros Masculino
#     </span>
# </div>

# %%
Filtro_Masculino=tabla['SEXO'].unique()
Filtro_Masculino
# Out:
# array(['MASCULINO', 'FEMENINO', 'NO DISPONIBLE'], dtype=object)

# %%
Filtro_Masculino=tabla[tabla['SEXO']=='MASCULINO']
Filtro_Masculino
# Out:
#                          DESCRIPCION_CONDUCTA                 ARMAS_MEDIOS  \
# 0                ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# 1                ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# 2                ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# 3                ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# 4                ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# ...                                       ...                          ...
# 100966  ARTÍCULO 229. VIOLENCIA INTRAFAMILIAR                 CONTUNDENTES
# 100968  ARTÍCULO 229. VIOLENCIA INTRAFAMILIAR          SIN EMPLEO DE ARMAS
# 100969  ARTÍCULO 229. VIOLENCIA INTRAFAMILIAR          SIN EMPLEO DE ARMAS
# 100983  ARTÍCULO 229. VIOLENCIA INTRAFAMILIAR          SIN EMPLEO DE ARMAS
# 100986  ARTÍCULO 229. VIOLENCIA INTRAFAMILIAR          SIN EMPLEO DE ARMAS
#
# ...

# %%
tabla['SEXO'].value_counts()
# Out:
# SEXO
# FEMENINO         46749
# MASCULINO        45133
# NO DISPONIBLE     9111
# Name: count, dtype: int64

# %% [markdown]
# <div align="center">
#     <span style="color:red; font-size:32px; font-weight:bold;">
#          Grafica de Victimas
#     </span>
# </div>

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax.bar(SEXO_1, tabla['SEXO'].value_counts(),color='c')
ax.set_title('Perfil de Victima')
ax.set_ylabel('Cantidad de personas')
ax.set_xlabel('SEXO')
ax.set_xticklabels
# Out:
# <bound method _AxesBase.set_xticklabels of <Axes: title={'center': 'Perfil de Victima'}, xlabel='SEXO', ylabel='Cantidad de personas'>>

# %% [markdown]
# <div align="center">
#     <span style="color:red; font-size:32px; font-weight:bold;">
#          EDADES
#     </span>
# </div>

# %%
tabla['EDAD'].value_counts()
# Out:
# EDAD
# NO DISPONIBLE    8836
# 30               3071
# 25               2900
# 28               2871
# 26               2846
#                  ...
# 84.0                2
# 3.0                 2
# 79.0                2
# 125                 1
# 92.0                1
# Name: count, Length: 184, dtype: int64

# %%
EDADES_1=tabla['EDAD'].unique()
EDADES_1
# Out:
# array(['21', '24', '23', '20', '22', '27', '29', '26', '28', '25', '18',
#        '19', '17', '16', '15', '33', '31', '34', '30', '32', '35', '37',
#        '39', '38', '36', '49', '46', '47', '45', '48', '40', '43', '44',
#        '41', '42', '51', '54', '53', '52', '50', '67', '71', '14', '13',
#        '12', '74', '75', 'NO DISPONIBLE', '63', '61', '87', '60', '56',
#        '69', '58', '57', '68', '65', '55', '85', '72', '59', '62', '70',
#        '79', '78', '5', '9', '66', '73', '64', '81', '77', '2', '0', '82',
#        '76', '83', '80', '6', '86', '84', '1', '90', '8', '10', '11', '3',
#        '7', '88', '92', '91', '89', '4', '93', '94', '95', nan, '125',
#        44.0, 51.0, 28.0, 33.0, 34.0, 58.0, 48.0, 27.0, 19.0, 35.0, 29.0,
#        26.0, 21.0, 83.0, 15.0, 56.0, 50.0, 18.0, 14.0, 37.0, 39.0, 62.0,
#        59.0, 47.0, 54.0, 40.0, 20.0, 53.0, 32.0, 41.0, 24.0, 42.0, 31.0,
#        23.0, 38.0, 22.0, 55.0, 72.0, 60.0, 45.0, 52.0, 49.0, 64.0, 43.0,
# ...

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax.bar(EDADES_1, tabla['EDAD'].value_counts(),color='g')
ax.set_title('Perfil de Victima')
ax.set_ylabel('Cantidad de personas')
ax.set_xlabel('EDAD')
ax.set_xticklabels(EDADES_1, rotation=90)
#ax.text(6-0.3,16500,'Hi',fontsize=8,color='red',fontweight='bold')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 fig, ax = plt.subplots(figsize=(8,4))
# ----> 2 ax.bar(EDADES_1, tabla['EDAD'].value_counts(),color='g')
#       3 ax.set_title('Perfil de Victima')
#       4 ax.set_ylabel('Cantidad de personas')
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
# ...

# %%
#fig, ax = plt.subplots(figsize=(8, 4))

# %%
#EDADES_1_str = [str(EDAD) for EDAD in EDADES_1]

# %%
#fig, ax = plt.subplots(figsize=(8,4))
#ax.bar(EDADES_1_str, tabla['EDAD'].value_counts(),color='g')
#ax.set_title('Perfil de Victima')
#ax.set_ylabel('Cantidad de personas')
#ax.set_xlabel('EDAD')
#ax.set_xticklabels(EDADES_1_str, rotation=90)
#ax.text(6-0.3,16500,'Hi',fontsize=8,color='red',fontweight='bold')

# %% [markdown]
# <div align="center">
#     <span style="color:red; font-size:32px; font-weight:bold;">
#          LOCALIDAD + TIPOLOGIA
#     </span>
# </div>

# %%
LOCALIDAD_1=tabla['LOCALIDAD'].unique()
LOCALIDAD_1
# Out:
# array(['11. SUR', '10. PROVENZA', '07. LA CIUDADELA', '06. LA CONCORDIA',
#        '15. CENTRO', '12. CABECERA DEL LLANO', '13. ORIENTAL',
#        '04. OCCIDENTAL', '03. SAN FRANCISCO', '02. NORORIENTAL',
#        '01. NORTE', '08. SUROCCIDENTE', '05. GARCIA ROVIRA',
#        '14. MORRORICO', '09. LA PEDREGOSA', '17. MUTIS',
#        '16. LAGOS DEL CACIQUE', 'NO DISPONIBLE', 'CORREGIMIENTO 1',
#        'CORREGIMIENTO 3', 'CORREGIMIENTO 2'], dtype=object)

# %%
tabla['LOCALIDAD'].value_counts()
# Out:
# LOCALIDAD
# 13. ORIENTAL              11898
# 03. SAN FRANCISCO         11678
# 15. CENTRO                10800
# 12. CABECERA DEL LLANO    10094
# 01. NORTE                  9316
# 06. LA CONCORDIA           6830
# 04. OCCIDENTAL             6669
# 05. GARCIA ROVIRA          5429
# 10. PROVENZA               5136
# 02. NORORIENTAL            4081
# 11. SUR                    3240
# 17. MUTIS                  2748
# 07. LA CIUDADELA           2485
# 16. LAGOS DEL CACIQUE      2410
# 14. MORRORICO              2407
# 08. SUROCCIDENTE           1944
# 09. LA PEDREGOSA           1928
# NO DISPONIBLE               856
# CORREGIMIENTO 3             493
# CORREGIMIENTO 1             383
# CORREGIMIENTO 2             168
# Name: count, dtype: int64

# %%
TIPOLOGÍA=tabla[tabla['TIPOLOGÍA']=='DELITOS CONTRA EL PATRIMONIO ECONOMICO']
TIPOLOGÍA.head()
# Out:
#            DESCRIPCION_CONDUCTA                 ARMAS_MEDIOS  \
# 0  ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# 1  ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# 2  ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# 3  ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# 4  ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
#
#          BARRIOS_HECHO FECHA_HECHO HORA_HECHO EDAD       SEXO MOVIL_VICTIMA  \
# 0              MALPASO  2019-06-17   20:30:00   21  MASCULINO         A PIE
# 1  GRANJAS DE PROVENZA  2019-09-12   01:30:00   21  MASCULINO         A PIE
# 2             PROVENZA  2019-04-07   05:10:00   21  MASCULINO         A PIE
# 3       CIUDAD VENECIA  2019-01-30   23:15:00   21  MASCULINO         A PIE
# 4             PROVENZA  2019-06-12   14:30:00   21  MASCULINO         A PIE
#
#   MOVIL_AGRESOR    CLASE_SITIO  ... DIA_NUM RANGO_HORARIO  \
# 0         A PIE  VIAS PUBLICAS  ...      17   20:00-20:59
# ...

# %%
#fig, ax = plt.subplots(figsize=(8,4))
#ax.bar(TIPOLOGÍA, tabla['TIPOLOGÍA'].value_counts(),color='g')
#ax.set_title('Perfil de Victima')
#ax.set_ylabel('Cantidad de personas')
#ax.set_xlabel('TIPOLOGÍA')
#ax.set_xticklabels(TIPOLOGÍA, rotation=90)
#ax.text(6-0.3,16500,'Hi',fontsize=8,color='red',fontweight='bold')

# %%
TIPOLOGÍA.query("LOCALIDAD=='11. SUR'")
# Out:
#                   DESCRIPCION_CONDUCTA                 ARMAS_MEDIOS  \
# 0         ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# 3         ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# 5         ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# 28        ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# 49        ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# ...                                ...                          ...
# 98847  ARTÍCULO 239. HURTO RESIDENCIAS                     PALANCAS
# 98855  ARTÍCULO 239. HURTO RESIDENCIAS                     PALANCAS
# 98864  ARTÍCULO 239. HURTO RESIDENCIAS                     PALANCAS
# 98871  ARTÍCULO 239. HURTO RESIDENCIAS          SIN EMPLEO DE ARMAS
# 98943  ARTÍCULO 239. HURTO RESIDENCIAS          SIN EMPLEO DE ARMAS
#
#          BARRIOS_HECHO FECHA_HECHO HORA_HECHO  EDAD       SEXO MOVIL_VICTIMA  \
# ...

# %%
tabla['TIPOLOGÍA'].value_counts()
# Out:
# TIPOLOGÍA
# DELITOS CONTRA EL PATRIMONIO ECONOMICO                         61990
# DELITOS CONTRA LA VIDA Y LA INTEGRIDAD PERSONAL                17436
# DELITOS CONTRA LA FAMILIA                                      13898
# DELITOS CONTRA LA SEGURIDAD PUBLICA                             4214
# DELITOS CONTRA LA LIBERTAD, INTEGRIDAD Y FORMACION SEXUALES     3454
# Name: count, dtype: int64

# %% [markdown]
# <div align="center">
#     <span style="color:red; font-size:32px; font-weight:bold;">
#          EL TIEMPO CON MAS DELITOS CONTRA EL PATRIMONIO ECONOMICO
#     </span>
# </div>

# %%
tabla["AÑO_NUM"].value_counts()
# Out:
# AÑO_NUM
# 2022    15750
# 2021    15369
# 2019    12892
# 2018    12479
# 2023    12366
# 2017    11004
# 2016    10770
# 2020    10363
# Name: count, dtype: int64

# %%
TIPOLOGÍA_año=tabla['TIPOLOGÍA'].unique()
TIPOLOGÍA_año
# Out:
# array(['DELITOS CONTRA EL PATRIMONIO ECONOMICO',
#        'DELITOS CONTRA LA LIBERTAD, INTEGRIDAD Y FORMACION SEXUALES',
#        'DELITOS CONTRA LA FAMILIA',
#        'DELITOS CONTRA LA VIDA Y LA INTEGRIDAD PERSONAL',
#        'DELITOS CONTRA LA SEGURIDAD PUBLICA', nan], dtype=object)

# %%
tabla['TIPOLOGÍA'].value_counts()
# Out:
# TIPOLOGÍA
# DELITOS CONTRA EL PATRIMONIO ECONOMICO                         61990
# DELITOS CONTRA LA VIDA Y LA INTEGRIDAD PERSONAL                17436
# DELITOS CONTRA LA FAMILIA                                      13898
# DELITOS CONTRA LA SEGURIDAD PUBLICA                             4214
# DELITOS CONTRA LA LIBERTAD, INTEGRIDAD Y FORMACION SEXUALES     3454
# Name: count, dtype: int64

# %%
TIPOLOGÍA=tabla[tabla['TIPOLOGÍA']=='DELITOS CONTRA EL PATRIMONIO ECONOMICO']
TIPOLOGÍA.head()
# Out:
#            DESCRIPCION_CONDUCTA                 ARMAS_MEDIOS  \
# 0  ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# 1  ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# 2  ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# 3  ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# 4  ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
#
#          BARRIOS_HECHO FECHA_HECHO HORA_HECHO EDAD       SEXO MOVIL_VICTIMA  \
# 0              MALPASO  2019-06-17   20:30:00   21  MASCULINO         A PIE
# 1  GRANJAS DE PROVENZA  2019-09-12   01:30:00   21  MASCULINO         A PIE
# 2             PROVENZA  2019-04-07   05:10:00   21  MASCULINO         A PIE
# 3       CIUDAD VENECIA  2019-01-30   23:15:00   21  MASCULINO         A PIE
# 4             PROVENZA  2019-06-12   14:30:00   21  MASCULINO         A PIE
#
#   MOVIL_AGRESOR    CLASE_SITIO  ... DIA_NUM RANGO_HORARIO  \
# 0         A PIE  VIAS PUBLICAS  ...      17   20:00-20:59
# ...

# %%
TIPOLOGÍA.query("AÑO_NUM=='2022'")
TIPOLOGÍA
# Out:
#                   DESCRIPCION_CONDUCTA                 ARMAS_MEDIOS  \
# 0         ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# 1         ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# 2         ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# 3         ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# 4         ARTÍCULO 239. HURTO PERSONAS  ARMA BLANCA / CORTOPUNZANTE
# ...                                ...                          ...
# 98964  ARTÍCULO 239. HURTO AUTOMOTORES          SIN EMPLEO DE ARMAS
# 98965  ARTÍCULO 239. HURTO AUTOMOTORES          SIN EMPLEO DE ARMAS
# 98966  ARTÍCULO 239. HURTO AUTOMOTORES          SIN EMPLEO DE ARMAS
# 98967  ARTÍCULO 239. HURTO AUTOMOTORES          SIN EMPLEO DE ARMAS
# 98968  ARTÍCULO 239. HURTO AUTOMOTORES          SIN EMPLEO DE ARMAS
#
#               BARRIOS_HECHO FECHA_HECHO HORA_HECHO EDAD           SEXO  \
# 0                   MALPASO  2019-06-17   20:30:00   21      MASCULINO
# ...

# %%
LOCALIDAD_1=filtro['LOCALIDAD'].unique()
LOCALIDAD_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 LOCALIDAD_1=filtro['LOCALIDAD'].unique()
#       2 LOCALIDAD_1
#
# NameError: name 'filtro' is not defined

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax.bar(LOCALIDAD_1, tabla['LOCALIDAD'].value_counts(),color='g')
ax.set_title('Perfil de Victima')
ax.set_ylabel('Cantidad de personas')
ax.set_xlabel('LOCALIDAD')
ax.set_xticklabels(LOCALIDAD_1, rotation=90)
#ax.text(6-0.3,16500,'Hi',fontsize=8,color='red',fontweight='bold')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 fig, ax = plt.subplots(figsize=(8,4))
# ----> 2 ax.bar(LOCALIDAD_1, tabla['LOCALIDAD'].value_counts(),color='g')
#       3 ax.set_title('Perfil de Victima')
#       4 ax.set_ylabel('Cantidad de personas')
#
# NameError: name 'LOCALIDAD_1' is not defined
